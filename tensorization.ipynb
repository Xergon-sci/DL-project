        0.7245679751,
        0.8518733505,
        0.9719112542,
        1.1644395297,
        1.1670845715,
        0.9757890528,
        0.8550620394,
        1.3102264591,
        1.3857466032,
        1.4665464035,
        1.465921272,
        2.0333522464,
        1.4557476002,
        5.3958855515,
        2.7551221977,
        1.7164911778,
        5.4873168409,
        0.1187003838,
        0.1187859219,
        0.1089260421,
        0.153984402,
        0.2145643007,
        0.1543587265,
        0.1267047873,
        0.2029128362,
        0.2147717677,
        0.4022486443,
        0.2622104483,
        0.2645463109,
        0.2304955097,
        0.5,
        0.5630309345,
        0.5644987453
    ],
    [
        0.7287974701,
        0.8734356995,
        0.9640722774,
        1.1845632486,
        1.3120498154,
        1.1096611936,
        0.9236746652,
        1.2407653046,
        1.231122969,
        1.2527817686,
        1.2887328877,
        1.9736426994,
        1.2864641917,
        4.2198677226,
        2.7720889232,
        2.1558689891,
        5.4652952878,
        0.1163948745,
        0.1195343568,
        0.1109835846,
        0.1468101623,
        0.2579370389,
        0.18316544,
        0.1375804856,
        0.1766230335,
        0.2077406337,
        0.4024585391,
        0.3195690098,
        0.388376004,
        0.2639543216,
        0.5630309345,
        0.5,
        0.5644572233
    ],
    [
        0.8580440233,
        1.0649355619,
        1.2604850817,
        1.6776976396,
        1.7362525118,
        1.3121311477,
        1.0834077692,
        1.9234259293,
        1.788137418,
        1.802603303,
        1.9628651446,
        3.2995548154,
        1.7362992729,
        5.1283863419,
        2.751806196,
        2.1270288539,
        5.49234317,
        0.1386482682,
        0.1375288132,
        0.1282750627,
        0.1912780597,
        0.3422022236,
        0.2020579645,
        0.1545913336,
        0.2247161396,
        0.2636618278,
        0.3258794977,
        0.3792566449,
        0.3156310487,
        0.2613790726,
        0.5644987453,
        0.5644572233,
        0.5
    ]
]

# %%
coulomb_vector = [
    36.8581051994,
    23.3624778679,
    14.0550913538,
    11.0706231346,
    9.5356203323,
    11.2819682136,
    16.8338712921,
    12.8700670281,
    11.7501369281,
    7.865453354,
    15.2642662066,
    14.5978968329,
    5.4751352366,
    5.523914611,
    5.48334674,
    1.7250404743,
    2.1981699113,
    1.4095355391,
    1.3292251904,
    1.3307628754,
    1.4449413978,
    1.9845267081,
    1.4507797332,
    2.2408201294,
    1.1721593239,
    1.1367976128,
    1.274038961,
    1.8468803485,
    2.2270623174,
    2.2474172175,
    1.742103647
]

# %%
import numpy as np
import math
# %matplotlib inline

def pad_matrix(matrix, size):
    """Applies padding to a matrix.
    You can use this function to scale a matrix to a given size.
    The empty space is filled with zeros.
    Example: Can be used to pad the Coulomb Matrix.
    Args:
        matrix (2D np.array): Matrix to pad in a nested list format.
        size (int): The size to scale the matrix to.
    Returns:
        ndarray: The padded matrix.
    """
    if isinstance(matrix, list):
        matrix = np.array(list)

    # calculate the wished size
    size = size - matrix.shape[0]

    # confirm the size isn't less than the default matrix size
    if size <= 0:
        m = matrix
        warnings.warn(
            "Trying to reduce the matrix size, default matrix size has been returned!",
            Warning,
        )
    else:
        # pad the matrix
        m = np.pad(matrix, (0, size))
    return m

def normalize(coulomb_matrix, phi=1, slope=1, negative_dimensions=0, positive_dimension=0):
    """Normalizes the Coulomb Matrix by tensorizing it. May require padding.
    This method is an adaption from (1).
    (1) Montavon, G.; Hansen, K.; Fazli, S.; Rupp, M.; Biegler, F.; Ziehe, A.;
    Tkatchenko, A.; Lilienfeld, A.; Müller, K.-R.
    Learning Invariant Representations of Molecules for Atomization Energy Prediction.
    In Advances in Neural Information Processing Systems;
    Pereira, F., Burges, C. J. C., Bottou, L., Weinberger, K. Q., Eds.;
    Curran Associates, Inc., 2012; Vol. 25.
    Args:
        coulomb_matrix (2D list): The Coulomb Matrix.
        phi (int, optional): Equivalent to an offset. Defaults to 1.
        slope (float, optional): The slope of the binarization function. Defaults to 0.7.
        negative_dimensions (int, optional): The amount of negative dimensions describing the tensor. Defaults to 0.
        positive_dimension (int, optional): The amount of positive dimensions describing the tensor. Defaults to 0.
    Returns:
        2D list: Tensorized Coulomb Matrix.
    """
    tensors = []
    cm = np.array(coulomb_matrix)

    # generate negative layers
    for i in range(negative_dimensions):
        tensor = np.empty([cm.shape[0], cm.shape[1]])
        for iy, y in enumerate(coulomb_matrix):
            for ix, x in enumerate(y):
                tensor[ix, iy] = (1/2)+((1/2)*math.tanh(((x-(i*phi))/phi)*slope))
        tensors.append(tensor)

    # generate base layer
    tensor = np.empty([cm.shape[0], cm.shape[1]])
    for iy, y in enumerate(coulomb_matrix):
        for ix, x in enumerate(y):
            tensor[ix, iy] = (1/2)+((1/2)*math.tanh((x/phi)*slope))
    tensors.append(tensor)

    # generate negapositive layers
    for i in range(positive_dimension):
        tensor = np.empty([cm.shape[0], cm.shape[1]])
        for iy, y in enumerate(coulomb_matrix):
            for ix, x in enumerate(y):
                tensor[ix, iy] = (1/2)+((1/2)*math.tanh(((x+(i*phi))/phi)*slope))
        tensors.append(tensor)
    return np.array(tensors)

# %%
coulomb_matrix = np.array(coulomb_matrix)
pad_mat = pad_matrix(coulomb_matrix, 63)
a = normalize(pad_mat)
a
# Out:
# array([[[1. , 1. , 1. , ..., 0.5, 0.5, 0.5],
#         [1. , 1. , 1. , ..., 0.5, 0.5, 0.5],
#         [1. , 1. , 1. , ..., 0.5, 0.5, 0.5],
#         ...,
#         [0.5, 0.5, 0.5, ..., 0.5, 0.5, 0.5],
#         [0.5, 0.5, 0.5, ..., 0.5, 0.5, 0.5],
#         [0.5, 0.5, 0.5, ..., 0.5, 0.5, 0.5]]])

# %%
def normalize_new(coulomb_matrix, phi=1, negative_dimensions=0, positive_dimensions=0):
    """Normalizes the Coulomb Matrix by tensorizing it. May require padding.
    This method is an adaption from (1).
    (1) Montavon, G.; Hansen, K.; Fazli, S.; Rupp, M.; Biegler, F.; Ziehe, A.;
    Tkatchenko, A.; Lilienfeld, A.; Müller, K.-R.
    Learning Invariant Representations of Molecules for Atomization Energy Prediction.
    In Advances in Neural Information Processing Systems;
    Pereira, F., Burges, C. J. C., Bottou, L., Weinberger, K. Q., Eds.;
    Curran Associates, Inc., 2012; Vol. 25.
    Args:
        coulomb_matrix (2D list): The Coulomb Matrix.
        phi (int, optional): Equivalent to an offset. Defaults to 1.
        negative_dimensions (int, optional): The amount of negative dimensions describing the tensor. Defaults to 0.
        positive_dimension (int, optional): The amount of positive dimensions describing the tensor. Defaults to 0.
    Returns:
        2D list: Tensorized Coulomb Matrix.
    """
    tensors = []
    cm = np.array(coulomb_matrix)
    
    def sigmoid(x):
        return np.exp(x)/(1+np.exp(x))

    # generate negative layers
    for i in range(-negative_dimensions, 0):
        tensor = sigmoid((cm+(i*phi))/phi) # gets i = negative here
        tensor = np.around(tensor, decimals=5)
        tensors.append(tensor)

    # generate base layer
    tensor = sigmoid(cm/phi)
    tensor = np.around(tensor, decimals=5)
    tensors.append(tensor)

    # generate positive layers
    for i in range(positive_dimensions):
        tensor = sigmoid((cm+(i*phi))/phi)
        tensor = np.around(tensor, decimals=5)
        tensors.append(tensor)
    return np.array(tensors)

# %%
t = normalize_new(pad_mat, negative_dimensions=0, positive_dimensions=100)
pd_tot = 63*63
print(t.shape)

posdim_tots = []
printed_p = False
for i in range(t.shape[0]):
    m = t[i].reshape((pd_tot,))
    current_tot = np.sum(m)
    posdim_tots.append(current_tot)
    if current_tot == pd_tot and printed_p==False:
        print('Current size:', current_tot, '/', pd_tot, 'at positive dimension', i)
        printed_p = True

del posdim_tots[0]
# Out:
# (101, 63, 63)
# Current size: 3969.0 / 3969 at positive dimension 14

# %%
t = normalize_new(pad_mat, negative_dimensions=100, positive_dimensions=0)
pd_tot = 0
print(t.shape)

negdim_tots = []
printed_n = False
for i in range(100, 0, -1):
    m = t[i].reshape((3969,))
    current_tot = np.sum(m)
    negdim_tots.append(current_tot)
    if current_tot == 1 and printed_n==False:
        print('Current size:', current_tot, '/', pd_tot, 'at negative dimension', 100-i)
        printed_n=True
# Out:
# (101, 63, 63)
# Current size: 1.0 / 0 at negative dimension 86

# %%
from qubit.descriptors import CoulombVector

# %%
pad_vec = CoulombVector.pad_vector(coulomb_vector, 63)

# %%
t = CoulombVector.normalize(pad_vec, negative_dimensions=0, positive_dimensions=50)
pd_tot = 63
print(t.shape)

posdim_tots_vec = []
printed_p = False
for i in range(t.shape[0]):
    m = t[i].reshape((pd_tot,))
    current_tot = np.sum(m)
    posdim_tots_vec.append(current_tot)
    if current_tot ==pd_tot and printed_p==False:
        print('Current size:', current_tot, '/', pd_tot, 'at positive dimension', i)
        printed_p = True
# Out:
# (51, 63)
# Current size: 63.0 / 63 at positive dimension 37

# %%
len(posdim_tots_vec)
# Out:
# 51

# %%
t = CoulombVector.normalize(pad_vec, negative_dimensions=50, positive_dimensions=0)
pd_tot = 0
print(t.shape)

negdim_tots_vec = []
printed_n = False
for i in range(50, 0, -1):
    m = t[i].reshape((63,))
    current_tot = np.sum(m)
    negdim_tots_vec.append(current_tot)
    if current_tot <1  and printed_n==False:
        print('Current size:', current_tot, '/', pd_tot, 'at negative dimension', 50-i)
        printed_n=True
# Out:
# (51, 63)
# Current size: 0.9976342681204118 / 0 at negative dimension 31

# %%
negdim_tots_vec
# Out:
# [44.34766408890603,
#  34.074686712435714,
#  25.46634658096498,
#  19.74866009423348,
#  16.505035798904377,
#  14.601298960385336,
#  13.253887305087188,
#  12.24433838845142,
#  11.441539738183446,
#  10.6794386067061,
#  9.822726810780344,
#  8.788630939587156,
#  7.625351711885777,
#  6.465508544209834,
#  5.349522755216257,
#  4.30020168346437,
#  3.417000931187028,
#  2.767381469539211,
#  2.355258596130674,
#  2.136502753023942,
#  2.024163325007201,
#  1.9355447393965366,
#  1.8041748478661512,
#  1.592594972782728,
#  1.3468927377681317,
#  1.163195997661705,
#  1.0668903873864972,
#  1.0256445279269804,
#  1.0094665652836425,
#  1.003169924217635,
#  1.0002614548700868,
#  0.9976342681204118,
#  0.9924723096810724,
#  0.9793937433164842,
#  0.9457601890795633,
#  0.8650847873483812,
#  0.7022678787537275,
#  0.4645868968823509,
#  0.24197308365525555,
#  0.10509121799517453,
#  0.04141189581455138,
#  0.015644104511403602,
#  0.005812625082369679,
# ...

# %%
import matplotlib.pyplot as plot
import matplotlib
matplotlib.rcParams['figure.dpi'] = 300

x_n = -np.array(range(len(negdim_tots), 0, -1))
x_p = np.array(range(0, len(posdim_tots)))

plot.plot(x_n, np.flip(negdim_tots), color='black')
plot.plot(x_p, posdim_tots, color='orange')
plot.fill_between(x_n, np.flip(negdim_tots), color='red', alpha=0.5, label='Negative data')
plot.fill_between(x_p, posdim_tots, (63*63), color='red', alpha=0.5, label='Positive data')
plot.title('Information by tensor dimensional layer')
plot.xlabel('Dimensional layers')
plot.gca().get_yaxis().set_visible(False)
plot.legend()
plot.savefig('cm_data.jpg')

# %%
import matplotlib.pyplot as plot
import matplotlib
matplotlib.rcParams['figure.dpi'] = 300

x_n = -np.array(range(len(negdim_tots_vec), 0, -1))
x_p = np.array(range(0, len(posdim_tots_vec)))

plot.plot(x_n, np.flip(negdim_tots_vec), color='black')
plot.plot(x_p, posdim_tots_vec, color='orange')
plot.fill_between(x_n, np.flip(negdim_tots_vec), color='red', alpha=0.5, label='Negative data')
plot.fill_between(x_p, posdim_tots_vec, 63, color='red', alpha=0.5, label='Positive data')
plot.title('Information by tensor dimensional layer')
plot.xlabel('Dimensional layers')
plot.gca().get_yaxis().set_visible(False)
plot.legend()
plot.savefig('cm_data.jpg')

# %%
from hurry.filesize import size

def calcMemory(x, count, augmentations):
    s = x.nbytes * count * augmentations
    return size(s)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-2246c54778eb> in <module>
# ----> 1 from hurry.filesize import size
#       2
#       3 def calcMemory(x, count, augmentations):
#       4     s = x.nbytes * count * augmentations
#       5     return size(s)
#
# ModuleNotFoundError: No module named 'hurry'

# %%
f = normalize_new(pad_mat, negative_dimensions=86, positive_dimensions=14)
f.shape

calcMemory(f, 1100, 100)

# %%
type(f)
